# %% [markdown]
# <a href="https://colab.research.google.com/github/KirillAnokhin/3sem/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns; sns.set_theme()

dim = 100
v = 2

arr_t = [t for t in range(dim)]
arr_x = [x for x in range(dim)]

arr_u = np.zeros((dim, dim))
arr_u[0][0] = 0
for t in range(1, dim, 1):
  arr_u[0][t] = math.sin(arr_t[t - 1] - 2*np.pi//arr_t[t]) 
for t in range(1, dim, 1):
  for x in range(1, dim, 1):
    arr_u[x][t] = arr_u[x-1][t-1]*(t - x//v)

# %%
ax = sns.heatmap(arr_u, vmin=0, vmax=1)
